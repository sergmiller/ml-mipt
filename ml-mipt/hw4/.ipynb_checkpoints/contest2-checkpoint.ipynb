# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sps
plt.style.use('ggplot')
from sympy import *
import copy
import re
from matplotlib import cm
from scipy import sparse
import scipy.sparse as sprs
from sklearn.svm import SVC
from scipy.sparse.csr import csr_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn import cross_validation
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, RandomForestClassifier
from joblib import Parallel, delayed
import multiprocessing
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

# %%
def get_good_train(name):
    id = 0
    ids = []
    word = []
    first_form = []
    part_first = []
    for line in open(name):
        line = re.split('[\,,+]',line[:-1])
        if line[0] == 'Id':
            continue
        for i in range(2, len(line),2):
            ids.append(id)
            word.append(line[1])
            first_form.append(line[i])
            part_first.append(line[i+1])
            id += 1
    frame = pd.DataFrame()
    frame['X'] = word
    frame['Y'] = first_form
    frame['P'] = part_first
    return frame

# %%
row_train=get_good_train('task2_lemmas_train')

# %%
row_train.head()
# Out:
#               X            Y  P  shifts
# 0  vergognerete   vergognare  V       5
# 1  amnistiavate   amnistiare  V       4
# 2   menomazione  menomazione  N       0
# 3    sfaldavamo     sfaldare  V       4
# 4    sfodererei    sfoderare  V       4

# %%
row_test = pd.read_csv('task2_lemmas_test')
row_test.columns = ['id', 'X']
row_test = row_test.drop('id',axis=1)

# %%
row_test.head()
# Out:
#                  X
# 0         gettonan
# 1      incidentali
# 2        involtino
# 3            lievi
# 4  comunistizzasse

# %%
np.unique(row_train['P'])
# Out:
# array(['A', 'N', 'V'], dtype=object)

# %%
def add_count_vectorizer_features(train, test):
    vectorizer = CountVectorizer(min_df=5, max_df=.7,
                             max_features=None,
                             ngram_range=(3, 5),
                             lowercase=False,
                             analyzer='char_wb', 
                             binary=True)
    TTrainM = vectorizer.fit_transform(train[0])
    TTestM = vectorizer.transform(test[0])
    return TTrainM, TTestM

def get_F_for_predict_part(train, test):
    CV_F_train, CV_F_test = add_count_vectorizer_features(train, test)
    chars = {'A':0,'N':1,'V':2}
    _P = np.array([chars[c] for c in train]).reshape(len(train['id']),1)
    return CV_F_train, CV_F_test, _P

# %%
def best_common_substr(s1, s2):
   m = [[0] * (1 + len(s2)) for i in range(1 + len(s1))]
   longest, x_longest = 0, 0
   for x in range(1, 1 + len(s1)):
       for y in range(1, 1 + len(s2)):
           if s1[x - 1] == s2[y - 1]:
               m[x][y] = m[x - 1][y - 1] + 1
               if m[x][y] > longest:
                   longest = m[x][y]
                   x_longest = x
           else:
               m[x][y] = 0
   return s1[x_longest - longest: x_longest]

def best_common_suff(s1, s2):
    pref = ''
    for i in range(min(len(s1), len(s2))):
        if s1[len(s1) - 1 - i] != s2[len(s2) - 1 - i]:
            break
        pref += s1[len(s1) - 1 - i]
    return pref

# %%
def best_common_prefix(s1, s2):
    pref = ''
    for i in range(min(len(s1), len(s2))):
        if s1[i] != s2[i]:
            break
        pref += s1[i]
    return pref

def extract_all_pref(train):
    prefs = dict()
    shifts = []
    for i in range(len(train)):
        w = train['X'][i]
        f = train['Y'][i]
        pref = best_common_prefix(w, f)
        part = train['P'][i]
        if pref not in prefs:
            prefs[pref] = dict()
        if part not in prefs[pref]:
            prefs[pref][part] = []
        prefs[pref][part].append(f)
        shifts.append(len(w) - len(pref))
    return prefs, shifts
                   
def extract_all_suff(train):
    prefs = dict()
    for i in range(len(train)):
        w = train['X'][i]
        f = train['Y'][i]
        pref = best_common_prefix(w, f)
        suff1 = w[len(pref):]
        suff2 = f[len(pref):]
        if len(suff1) <= 1:
            continue
        if suff1 in prefs:
            if len(suff2) > len(prefs[suff1][0]):
                continue
        prefs[suff1] = (suff2,train['P'][i])
    return prefs

# %%
# %%time
prefs,shifts =  extract_all_pref(row_train)
# Out:
# CPU times: user 15.5 s, sys: 332 ms, total: 15.8 s
# Wall time: 17.4 s

# %%
def add_column(frame, data, names):
    new_fr = pd.DataFrame(data, columns=names)
    return pd.concat((frame, new_fr),axis=1)

# %%
row_train = add_column(row_train, shifts, ['shifts'])

# %%
row_train.head()
# Out:
#               X            Y  P  shifts
# 0  vergognerete   vergognare  V       5
# 1  amnistiavate   amnistiare  V       4
# 2   menomazione  menomazione  N       0
# 3    sfaldavamo     sfaldare  V       4
# 4    sfodererei    sfoderare  V       4

# %%
def predict_with_substr(test, prefs):
    bad = 0
    pred  = []
    for s in test['X']:
        er = 1
        found = None
        best = None
        for i in range(len(s)):
                for j in range(i+1,len(s)):
                    cur = s[i:j]
                    if cur in substrs:
                        if found is None or len(cur) > found:
                            found = len(cur)
                            best = cur
                            er = 0
        if best is not None:
            pred.append(substrs[best][0] + '+' + substrs[best][1])
                            
        if er == 1:
            bad += 1
            pred.append(s + '+V')
    return pred,bad

# %%
def predict_with_suff(test, prefs):
    bad = 0
    pred  = []
    for s in test['X']:
        er = 1
        for i in range(len(s)-1,-1,-1):
            cur = s[i:]
            if cur in suffs:
                pred.append(s[:-len(cur)] + suffs[cur][0] + '+' + suffs[cur][1])
                er = 0
                break
                                    
        if er == 1:
            bad += 1
            pred.append(s + '+V')
    return pred,bad

# %%
def predict_with_prefs(test, prefs, offsets):
    bad = 0
    pred  = []
    i = 0
    for s in test['X']:
        er = 1
        for i in range(len(s) - offsets[i]):
            cur = s[i:len(s) - offsets[i]]
            if cur in prefs:
                pred.append(prefs[cur])
                er = 0
                break
        if er == 1:
            bad += 1
            pred.append(None)
        i += 1
        
    return pred,bad

# %%
i = 0 
for v in prefs:
    print(prefs[v])
    i += 1
    if i == 20:
        break
# Out:
# {'V': {'vergognare'}, 'N': {'vergogna'}}
# {'V': {'amnistiare'}, 'A': {'amnistiare'}}
# {'N': {'menomazione'}}
# {'V': {'sfaldare'}}
# {'V': {'sfoderare'}}
# {'V': {'ascondere'}}
# {'V': {'edificare'}}
# {'V': {'maschiare'}, 'A': {'maschio'}}
# {'V': {'transennare'}, 'N': {'transenna'}}
# {'V': {'computare'}, 'A': {'computare'}}
# {'V': {'accudire'}}
# {'V': {'dirompere'}}
# {'V': {'intercollegare'}}
# {'V': {'integrare'}}
# {'V': {'sbramare'}}
# {'V': {'stravaccare'}}
# {'V': {'oltrepassare'}}
# {'V': {'cauzionare'}}
# {'V': {'scarrozzare'}, 'A': {'scarrozzare'}}
# {'V': {'intossicare'}}

# %%
many = [prefs[v] for v in prefs if prefs[v] is not None 
        and 
        (('V' in prefs[v] and prefs[v]['V'] is not None and len(prefs[v]['V']) > 1) or
         ('A' in prefs[v] and prefs[v]['A'] is not None and len(prefs[v]['A']) > 1) or
         ('N'in prefs[v] and prefs[v]['N'] is not None and len(prefs[v]['N']) > 1))
         ]
print(len(many), len(many)/len(y_pred), many)
# Out:
# 139 0.004686288392164796 [{'V': {'soffriggere', 'soffrire'}}, {'V': {'corrompere', 'correre'}}, {'V': {'accorgere', 'accorare'}}, {'V': {'infiltrarsi', 'infiltrare'}}, {'N': {'gobba', 'gobbo'}}, {'V': {'creare', 'crescere'}}, {'A': {'indicatore', 'indicato'}}, {'N': {'cappella', 'cappello'}}, {'V': {'falcare', 'falciare'}}, {'V': {'rischiarare', 'rischiare'}}, {'V': {'spiare'}, 'A': {'spiare', 'spia'}}, {'V': {'astrologare'}, 'N': {'astrologo', 'astrologa'}}, {'N': {'infermiera', 'infermiere'}}, {'V': {'potere', 'potare'}}, {'V': {'protestare'}, 'N': {'protesta', 'protesto'}}, {'V': {'rimanere', 'rimare'}}, {'V': {'scuotere', 'essere', 'percuotere', 'consistere', 'risedere', 'uscire', 'esistere', 'desistere'}, 'A': {'ripercuotere', 'buono', 'risedere', 'grande'}}, {'V': {'corrodere', 'corrompere'}}, {'V': {'pendolare'}, 'N': {'pendola', 'pendolo'}}, {'A': {'scarno', 'scarnire'}}, {'A': {'penultimo'}, 'N': {'penultimo', 'penultima'}}, {'N': {'depressa', 'depresso'}}, {'V': {'mordere', 'morire'}, 'A': {'moro'}, 'N': {'moro', 'mora'}}, {'V': {'ramare'}, 'N': {'ramo', 'rame'}}, {'N': {'brocca', 'brocco'}}, {'N': {'manomorta', 'mano', 'man'}}, {'V': {'risolvere', 'risolare'}}, {'N': {'commissaria', 'commissario'}, 'V': {'commissariare'}}, {'N': {'bustino', 'bustina'}}, {'A': {'fino', 'finire'}}, {'A': {'sollevato', 'sollevatore'}}, {'A': {'debito', 'debitore'}, 'N': {'debito'}}, {'V': {'empire', 'empiere'}, 'A': {'empio'}}, {'N': {'fallo', 'falla'}, 'A': {'fallire'}}, {'V': {'animare'}, 'N': {'anima', 'animo'}}, {'V': {'soprassedere'}, 'A': {'soprassedere', 'sedere'}}, {'V': {'permeare', 'permettere'}}, {'N': {'capanno', 'capanna'}}, {'A': {'prim', 'primo'}, 'N': {'primadonna'}}, {'V': {'marciare', 'marcare'}, 'N': {'marca', 'marcia'}}, {'A': {'brutto', 'brutt'}, 'N': {'brutto'}}, {'V': {'decorrere', 'decorare'}}, {'V': {'spillare'}, 'N': {'spillo', 'spilla'}}, {'N': {'cassetto', 'cassetta'}}, {'A': {'comico', 'comic'}}, {'V': {'mostrare'}, 'N': {'mostra', 'mostro'}}, {'N': {'lirica', 'lirico'}}, {'N': {'tiro', 'tir'}}, {'V': {'commuovere', 'commettere'}}, {'N': {'botte', 'botto'}}, {'A': {'riparatore', 'riparato'}}, {'N': {'sete', 'set', 'seta'}}, {'N': {'campanello', 'campanella'}}, {'V': {'infiltrarsi', 'infiltrare'}}, {'N': {'novello', 'novella'}, 'A': {'novello'}}, {'V': {'pacificare'}, 'N': {'pacifica', 'pacifico'}}, {'A': {'second', 'secondo'}, 'V': {'secondare'}, 'N': {'secondo'}}, {'A': {'nefasto'}, 'N': {'nefasto', 'nefasta'}}, {'A': {'unionista', 'unionisto'}, 'N': {'unionista'}}, {'N': {'pena', 'pene'}}, {'N': {'piatto', 'piatta'}}, {'V': {'sfiorare', 'sfiorire'}}, {'N': {'romeno', 'romena'}}, {'N': {'veterana', 'veterano'}}, {'N': {'palo', 'pala'}}, {'N': {'mantella', 'mantello'}}, {'V': {'mettere', 'morire'}}, {'V': {'addire', 'addurre'}}, {'V': {'spandere', 'sparire'}}, {'N': {'raffinata', 'raffinato'}}, {'N': {'scienziata', 'scienziato'}}, {'A': {'fenicio', 'fenico'}}, {'N': {'bar', 'baro'}}, {'N': {'veneziana', 'veneziano'}}, {'N': {'elaborato'}, 'A': {'elaboratore', 'elaborato'}}, {'N': {'capolista', 'capogruppo', 'capa', 'capopattuglia', 'capoclan'}, 'A': {'capire'}}, {'N': {'razza', 'razzo'}}, {'N': {'psicologo', 'psicologa'}}, {'N': {'grill', 'grillo'}}, {'N': {'calco', 'calce'}}, {'A': {'ispiratore', 'ispirato'}}, {'V': {'trattare', 'trattenere'}, 'N': {'tratto'}}, {'N': {'fauna', 'fauno'}}, {'N': {'cartello', 'cartella'}}, {'V': {'ridurre', 'ridire'}}, {'N': {'superbo', 'superba'}}, {'A': {'fiduciario'}, 'N': {'fiduciaria', 'fiduciario'}}, {'N': {'pallina', 'pallino'}}, {'A': {'guerriero'}, 'N': {'guerriero', 'guerriera'}}, {'A': {'modern', 'moderno'}}, {'N': {'balla', 'ballo'}, 'V': {'ballare'}}, {'N': {'devoto', 'devota'}}, {'A': {'bravo', 'brav'}, 'N': {'brava'}}, {'A': {'negato', 'negatore'}}, {'A': {'unificato', 'unificatore'}}, {'A': {'romanzo'}, 'N': {'romanzo', 'romanza'}}, {'N': {'signorina', 'signorino'}}, {'N': {'cera', 'cero'}}, {'N': {'cassaforte', 'cassa'}}, {'A': {'grand', 'grande'}}, {'N': {'b ...

# %%
# Out:
# CPU times: user 72.5 ms, sys: 3.16 ms, total: 75.6 ms
# Wall time: 76.4 ms

# %%
mult
# Out:
# 6042

# %%
print(mult, bad, len(y_pred), (len(y_pred) - mult - bad)/len(y_pred), mult/len(y_pred), bad/len(y_pred))
# Out:
# 6042 329 29661 0.7852061629749503 0.2037018306867604 0.011092006338289336

# %%
y_pred[1000:1020]
# Out:
# [{'A': {'porgere'}},
#  {'V': {'espungere'}},
#  {'V': {'arcaizzare'}},
#  {'N': {'settore'}},
#  {'A': {'centesimo'}, 'N': {'centesimo'}},
#  None,
#  {'V': {'canterellare'}},
#  {'A': {'rinunciatario'}},
#  {'V': {'presupporre'}},
#  {'V': {'insorgere'}},
#  {'V': {'seghettare'}},
#  {'V': {'calamitare'}},
#  {'A': {'sfamare'}, 'V': {'sfamare'}},
#  {'V': {'sobbarcare'}},
#  {'A': {'grippare'}, 'V': {'grippare'}},
#  {'N': {'schematizzazione'}},
#  {'A': {'mobiliare'}},
#  {'V': {'sgombrare'}},
#  {'N': {'accento'}, 'V': {'accentare'}},
#  {'V': {'respingere'}}]

# %%
mult_eq = [ y for y in y_pred 
       if y is not None and len(y) == 2 and list(y)[0][0] == list(y)[1][0]]
print(len(mult_eq), len(mult_eq)/len(y_pred), mult_eq)
# Out:
# 4367 0.14723036984592563 [{('comunistizzare', 'V'), ('comunistizzare', 'A')}, {('imbrodare', 'V'), ('imbrodare', 'A')}, {('elettrizzare', 'A'), ('elettrizzare', 'V')}, {('distinguere', 'V'), ('distinguere', 'A')}, {('fertilizzare', 'A'), ('fertilizzare', 'V')}, {('decantare', 'V'), ('decantare', 'A')}, {('scapitare', 'V'), ('scapitare', 'A')}, {('sgomentare', 'A'), ('sgomentare', 'V')}, {('standardizzare', 'A'), ('standardizzare', 'V')}, {('decadente', 'A'), ('decadente', 'N')}, {('arricciare', 'A'), ('arricciare', 'V')}, {('posizionare', 'A'), ('posizionare', 'V')}, {('bisbocciare', 'V'), ('bisbocciare', 'A')}, {('rimembrare', 'A'), ('rimembrare', 'V')}, {('controfirmare', 'V'), ('controfirmare', 'A')}, {('incatramare', 'V'), ('incatramare', 'A')}, {('affascinare', 'V'), ('affascinare', 'A')}, {('distinguere', 'V'), ('distinguere', 'A')}, {('espungere', 'A'), ('espungere', 'V')}, {('assicurare', 'A'), ('assicurare', 'V')}, {('speronare', 'V'), ('speronare', 'A')}, {('rubacchiare', 'A'), ('rubacchiare', 'V')}, {('inquadrare', 'V'), ('inquadrare', 'A')}, {('mummificare', 'A'), ('mummificare', 'V')}, {('intingere', 'A'), ('intingere', 'V')}, {('insinuare', 'V'), ('insinuare', 'A')}, {('erigere', 'A'), ('erigere', 'V')}, {('impalcare', 'V'), ('impalcare', 'A')}, {('destrutturare', 'A'), ('destrutturare', 'V')}, {('chioccolare', 'A'), ('chioccolare', 'V')}, {('crocidare', 'V'), ('crocidare', 'A')}, {('leggicchiare', 'V'), ('leggicchiare', 'A')}, {('solubilizzare', 'A'), ('solubilizzare', 'V')}, {('rischiarare', 'A'), ('rischiarare', 'V')}, {('stellare', 'A'), ('stellare', 'V')}, {('comprovare', 'A'), ('comprovare', 'V')}, {('vaticinare', 'V'), ('vaticinare', 'A')}, {('sedurre', 'V'), ('sedurre', 'A')}, {('districare', 'A'), ('districare', 'V')}, {('dissanguare', 'A'), ('dissanguare', 'V')}, {('coalizzare', 'V'), ('coalizzare', 'A')}, {('abboccare', 'V'), ('abboccare', 'A')}, {('standardizzare', 'A'), ('standardizzare', 'V')}, {('rivelare', 'A'), ('rivelare', 'V')}, {('decomprimere', 'V'), ('decomprimere', 'A')}, {('aggrinzare', 'A'), ('aggrinzare', 'V')}, {('naufragare', 'A'), ('naufragare', 'V')}, {('riconsiderare', 'A'), ('riconsiderare', 'V')}, {('confederare', 'A'), ('confederare', 'V')}, {('spiumare', 'V'), ('spiumare', 'A')}, {('buttare', 'A'), ('buttare', 'V')}, {('ereditare', 'V'), ('ereditare', 'A')}, {('contabile', 'N'), ('contabile', 'A')}, {('imbrattare', 'A'), ('imbrattare', 'V')}, {('mozzare', 'A'), ('mozzare', 'V')}, {('pettinare', 'V'), ('pettinare', 'A')}, {('tostare', 'V'), ('tostare', 'A')}, {('informare', 'V'), ('informare', 'A')}, {('villeggiare', 'A'), ('villeggiare', 'V')}, {('stravolgere', 'V'), ('stravolgere', 'A')}, {('addolorare', 'A'), ('addolorare', 'V')}, {('autocontrollare', 'A'), ('autocontrollare', 'V')}, {('assecondare', 'V'), ('assecondare', 'A')}, {('manifestare', 'V'), ('manifestare', 'A')}, {('interstellare', 'A'), ('interstellare', 'V')}, {('riaffacciare', 'A'), ('riaffacciare', 'V')}, {('incordare', 'V'), ('incordare', 'A')}, {('disinfiammare', 'V'), ('disinfiammare', 'A')}, {('strumentalizzare', 'V'), ('strumentalizzare', 'A')}, {('dedurre', 'V'), ('dedurre', 'A')}, {('posticipare', 'V'), ('posticipare', 'A')}, {('naufragare', 'A'), ('naufragare', 'V')}, {('truccare', 'A'), ('truccare', 'V')}, {('interstellare', 'A'), ('interstellare', 'V')}, {('indonesiano', 'N'), ('indonesiano', 'A')}, {('affaticare', 'A'), ('affaticare', 'V')}, {('rinzaffare', 'A'), ('rinzaffare', 'V')}, {('allontanare', 'V'), ('allontanare', 'A')}, {('appassire', 'A'), ('appassire', 'V')}, {('afferrare', 'A'), ('afferrare', 'V')}, {('spaziare', 'A'), ('spaziare', 'V')}, {('smerlare', 'V'), ('smerlare', 'A')}, {('svasare', 'V'), ('svasare', 'A')}, {('spericolato', 'N'), ('spericolato', 'A')}, {('ingraziare', 'A'), ('ingraziare', 'V')}, {('sterilizzare', 'A'), ('sterilizzare', 'V')}, {('faticare', 'V'), ('faticare', 'A')}, {('posticipare', 'V'), ('posticipare', 'A')}, {('sventagliare', 'A'), ('sventagliare', 'V')}, {('sfi ...

# %%
pairs_in_ord = [y[-1][1] for y in y_pred_ords 
                if y is not None and 
                len(set(y)) > 1
               ]

# %%
print(len(pairs_in_ord), len(pairs_in_ord)/len(y_pred), pairs_in_ord)
# Out:
# 6249 0.21068069181753818 ['V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'A', 'V', 'A', 'V', 'V', 'A', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'N', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'A', 'A', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'N', 'V', 'V', 'A', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'A', 'V', 'V', 'V', 'A', 'V', 'A', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'A', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'N', 'A', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'A', 'A', 'A', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'A', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'A', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'N', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'A', 'V', 'V', 'V', 'V', 'A', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'N', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'N', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'A', 'A', 'V', 'A', 'V', 'V', 'V', 'V', 'V', 'A', 'V', 'V', 'V', 'V', 'V', ...

# %%
len([y for y in pairs_in_ord if y == 'V'])
# Out:
# 5453

# %%
def add_column(_frame, data, names):
    new_fr = pd.DataFrame(data, columns=names)
    return pd.concat((_frame, new_fr),axis=1)

def add_custom(frame, f, name):
    data = np.array([f(x) for x in frame['X']]).reshape((len(frame['X']),1))
    return add_column(frame, data, [name])

def normalize(frame, name):
    frame[name] = (np.array(frame[name]) - np.mean(frame[name]))/np.std(frame[name])
    return frame

def add_count_vectorizer_features(train, test):
    vectorizer = CountVectorizer(min_df=2, max_df=.9,
                             max_features=None,
                             ngram_range=(2, 10),  # 5 --> 10
                             lowercase=True,
                             analyzer='char_wb', 
                             binary=False)
    TTrainM = vectorizer.fit_transform(train['X'])
    TTestM = vectorizer.transform(test['X'])
    return TTrainM, TTestM

def add_custom_features(train, test):
    _Train = normalize(add_custom(train, (lambda s: len(s)),'_len'),'_len')
    _Test = normalize(add_custom(test, (lambda s: len(s)),'_len'),'_len')
    _Train = _Train.drop(['X','Y','P','shifts'],axis=1)
    _Test = _Test.drop(['X'],axis=1)
    if 'Y' in _Test.columns and 'P' in _Test.columns and 'shifts' in _Test.columns:
        _Test = _Test.drop(['Y','P','shifts'],axis=1)
    return np.array(_Train,dtype=float), np.array(_Test,dtype=float)

def gen_features_frames(train, test):
    train_vect, test_vect = add_count_vectorizer_features(train, test)
    train_my_f, test_my_f = add_custom_features(train, test)
    Train = sprs.hstack([train_vect, sprs.coo_matrix(train_my_f)])
    Test = sprs.hstack([test_vect, sprs.coo_matrix(test_my_f)])
    return Train, Test

def convert_classes(train_ans):
    d = {'A':0, 'N':1, 'V':2}
    return np.array([d[c] for c in train_ans])

def revert_classes(train_ans):
    d = ['A','N','V']
    return np.array([d[c] for c in train_ans])

# %%
from joblib import Parallel, delayed
import multiprocessing

# %%
def do(train_indices, test_indices, Train, Y,clf, y_name='P'):
    Train_train = Train.loc[train_indices]
    Train_test = Train.loc[test_indices]
    Train_train.index = np.arange(len(train_indices))
    Train_test.index = np.arange(len(test_indices))
    x_train, x_test = gen_features_frames(Train_train, Train_test)
    y_train = Y[train_indices]
    y_test = Y[test_indices]
    clf.fit(sprs.coo_matrix(x_train),y_train)
    y_pred = clf.predict(sprs.coo_matrix(x_test))
    return accuracy_score(y_test, y_pred)


def cross_val(Train, clf, y_name='P', folds=4, jobs=1):
    score = []
    Y = Train[y_name]
    if y_name == 'P':
        Y = convert_classes(Y)
    score = Parallel(n_jobs=jobs)(delayed(do)(train_indices, test_indices, Train, Y,clf, y_name)
                               for train_indices, test_indices 
                               in cross_validation.KFold(len(Y), n_folds = folds))
    return [np.mean(score), np.std(score)]

def pred_parts(Train, Test, clf, y_name = 'P'):
    Y = Train[y_name]
    if y_name == 'P':
        Y = convert_classes(Y)
    train, test = gen_features_frames(Train, Test)
    clf.fit(train, Y)
    y_pred = clf.predict(test)
    return y_pred

# %%
clfs = [
        LogisticRegression(penalty='l1',
                    max_iter=100,
                    C=1,
                    class_weight='balanced',
                    n_jobs=4,
                    verbose=True),
]

# %%
# %%time
ans = []
for clf in clfs:
    ans.append(cross_val(row_train, clf,'shifts', 4,4))
    print(ans[-1])
# Out:
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:920: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:920: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:920: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:920: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [0.91065950169257304, 0.0012740327875784417]
# CPU times: user 668 ms, sys: 386 ms, total: 1.05 s
# Wall time: 1min 58s

# %%
# %%time
classes = pred_parts(row_train, row_test, clfs[0])

# %%
# %%time
offsets = pred_parts(row_train, row_test, clfs[0], 'shifts')
# Out:
# [LibLinear]CPU times: user 2min 53s, sys: 4.86 s, total: 2min 58s
# Wall time: 3min 10s

# %%
offsets
# Out:
# array([1, 1, 3, ..., 1, 4, 7])

# %%
balanced,l1, binary, C=10 -[0.95773262288395533, 0.001451525583466166]
multiclass,l2,newton,C=10,iter-100 0.96
multiclass,l2,lbgfs,C=10,iter-200 0.94

# %%
def get_pred_with_prefs_and_classes(y_pred, words, classes):
    ans = []
    i = 0
    for y in y_pred:
        if y is not None:
            if classes[i] in y:
                ans.append(list(sps.mode(y[classes[i]])[0][0])[0] + '+' + classes[i])
            else:
                if 'V' in y:
                    ans.append(list(sps.mode(y['V'])[0][0])[0] + '+V')
                else:
                    ans.append(list(sps.mode(y[[k for k in y][0]])[0][0])[0] + '+' + [k for k in y][0])
        else:
            ans.append(words[i] + '+V')
        i += 1
    return ans

# %%
# %%time
y_pred,bad = predict_with_prefs(row_test, prefs, offsets) 
mult = len([y for y in y_pred if y is not None and len(y) > 1])
# Out:
# CPU times: user 143 ms, sys: 2.82 ms, total: 146 ms
# Wall time: 147 ms

# %%
y_pred[0:20]
# Out:
# [{'V': ['gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare',
#    'gettonare']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'A': ['imbrodare', 'imbrodare'],
#   'V': ['imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare',
#    'imbrodare']},
#  {'V': ['strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare',
#    'strillare']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'A': ['soprassedere', 'sedere'],
#   'V': ['soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere',
#    'soprassedere']},
#  {'V': ['cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire',
#    'cucire']},
#  {'N': ['bava']},
#  None,
#  {'V': ['coagulare', 'coagulare', 'coagulare']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'N': ['era'],
#   'V': ['ergere', 'ergere', 'ergere', 'ergere', 'ergere', 'ergere', 'ergere']},
#  {'A': ['essere'],
#   'V': ['essere', 'essere', 'essere', 'essere', 'essere', 'essere']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'A': ['grande',
#    'risedere',
#    'grande',
#    'buono',
#    'grande',
#    'grande',
#    'ripercuotere',
#    'grande'],
#   'V': ['scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'uscire',
#    'desistere',
#    'esistere',
#    'consistere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'uscire',
#    'essere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'desistere',
#    'esistere',
#    'consistere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'uscire',
#    'risedere',
#    'uscire',
#    'essere',
#    'risedere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'risedere',
#    'uscire',
#    'uscire',
#    'uscire',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'risedere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'scuotere',
#    'percuotere',
#    'essere',
#    'essere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere',
#    'essere',
#    'scuotere',
#    'percuotere',
#    'risedere']},
#  {'V': ['risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare',
#    'risucchiare']}]

# %%
# %%time
y_pred_full = get_pred_with_prefs_and_classes(y_pred, row_test['X'], classes)
# Out:
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# CPU times: user 3.2 s, sys: 37.9 ms, total: 3.24 s
# Wall time: 3.29 s

# %%
def save_ans(_y_test, filename):
    print(_y_test)
    names = np.arange(len(_y_test)) + 1
    ans = pd.DataFrame(data=np.matrix(_y_test).T, columns=['Category'])
    ans = pd.concat((pd.DataFrame(names,columns=['Id']),ans),axis=1)
    ans.to_csv(filename,index=None)

# %%
save_ans(y_pred_full, 'contest2_best_pref_dict_with_predict_class_and_offset')
# Out:
# ['g+V', 'g+A', 'e+V', 'e+V', 'e+V', 'e+V', 'i+V', 's+V', 'e+V', 's+V', 'c+V', 'b+N', 'tesseron+V', 'c+V', 'e+V', 'e+N', 'e+V', 'e+V', 'e+V', 'r+V', 's+A', 't+A', 'e+V', 'e+V', 'e+V', 'r+V', 'e+V', 'i+V', 't+V', 'c+V', 'd+V', 'e+V', 'r+V', 'e+V', 'e+V', 'r+V', 'e+V', 'e+V', 'r+V', 'a+N', 'sgobbano+V', 'e+V', 'e+V', 'e+V', 'p+N', 's+V', 'f+A', 'e+V', 'r+V', 'autoalimentavamo+V', 'e+V', 's+A', 'e+V', 'e+V', 'e+V', 'f+V', 'p+V', 'e+V', 'scomponibili+V', 'e+V', 'e+V', 'e+V', 'e+V', 'e+V', 'e+V', 'o+N', 'cotonerei+V', 'f+V', 'g+A', 'e+V', 't+N', 'g+A', 's+V', 'e+V', 'e+V', 'e+V', 'i+A', 'z+N', 'impecerai+V', 's+V', 'e+V', 'e+V', 'e+V', 'astrologhi+V', 'g+A', 'e+V', 'r+V', 'e+V', 'd+V', 'm+V', 'viados+V', 'mangiucchiassi+V', 'guaiscono+V', 'b+A', 'e+V', 'u+A', 'e+V', 'l+N', 'a+V', 'd+A', 'z+N', 'a+V', 'e+V', 'r+V', 'r+V', 'r+V', 'd+A', 'e+V', 'e+V', 'r+A', 'aiole+V', 'c+V', 'c+V', 'e+V', 'e+V', 'p+V', 'e+V', 'r+V', 'e+V', 'e+V', 'e+V', 'e+V', 't+N', 'p+V', 'g+V', 'a+N', 'p+V', 'g+A', 'e+V', 'e+V', 'r+V', 'e+V', 'e+V', 'f+A', 'i+V', 's+V', 'm+A', 'sillogizzava+V', 'sgelan+V', 's+V', 'e+V', 'c+A', 'e+V', 'e+V', 'c+A', 'd+N', 'o+N', 'e+V', 'e+V', 'e+V', 'e+V', 'e+V', 'e+V', 'p+N', 'e+V', 'e+V', 'o+N', 'p+V', 'riallunghino+V', 'appunteremmo+V', 'c+A', 'v+A', 'e+V', 'e+V', 'b+V', 'i+V', 'a+V', 'e+V', 'e+V', 'sovrapproduzioni+V', 'c+V', 'm+V', 'e+V', 's+V', 'p+V', 'e+V', 'p+V', 'e+V', 't+V', 'molcei+V', 'e+V', 'c+A', 'e+V', 'b+A', 's+N', 's+V', 'm+V', 's+V', 'i+V', 'r+V', 'e+V', 'spierebber+V', 'ritagliassero+V', 'a+V', 'i+V', 'emulavo+V', 'e+V', 'e+V', 'a+N', 'l+N', 'd+V', 'e+V', 'r+A', 'i+A', 'e+V', 'c+V', 'e+V', 'e+V', 'd+A', 'e+V', 'e+V', 'o+N', 'normalizzereste+V', 'decontestualizzavan+V', 'e+V', 'e+V', 'p+A', 'abbottonasse+V', 'fiocineresti+V', 'e+V', 'g+A', 'a+N', 'e+V', 'i+V', 'c+A', 't+N', 'assicurante+V', 'tronchi+V', 'm+V', 'e+V', 'e+V', 'e+V', 'e+V', 'r+A', 's+V', 'e+V', 'e+V', 'l+N', 'q+A', 'e+V', 'e+V', 'e+V', 's+A', 'r+V', 's+V', 'rincantucciasser+V', 'mummificammo+V', 'e+V', 'e+V', 'e+V', 'p+V', 'p+N', 'e+V', 's+V', 'o+N', 's+A', 'magnetizzano+V', 'imbandieraste+V', 'e+V', 'e+V', 'r+A', 'e+V', 'b+A', 'e+V', 'e+V', 'r+V', 'v+N', 'e+V', 'e+V', 'e+V', 'd+N', 'e+V', 'm+N', 'e+V', 'e+V', 'r+V', 'e+V', 'g+A', 't+V', 'entrerebbe+V', 'e+V', 'e+V', 'd+N', 'e+V', 'r+V', 'rischiarassero+V', 'a+V', 'e+V', 'r+V', 's+V', 'p+N', 'r+V', 'b+N', 'e+V', 'e+V', 'e+V', 'r+V', 'intrighin+V', 'rieducherebbero+V', 'sbiancata+V', 'd+A', 'd+V', 'r+V', 'c+V', 'g+A', 'r+V', 'r+N', 'e+V', 'e+V', 'r+V', 'e+V', 'a+V', 'l+N', 'e+V', 'g+A', 'i+V', 's+V', 'e+V', 'c+V', 'r+V', 's+A', 'd+N', 'stimmatizzaron+V', 'r+V', 'ridirai+V', 'e+V', 'noto+V', 'e+V', 'e+V', 'r+V', 't+V', 'e+V', 'r+V', 'i+A', 'e+V', 'i+A', 's+A', 'abboccassi+V', 'e+V', 'g+A', 'm+V', 'o+N', 'corrivo+V', 'e+V', 'beccano+V', 's+V', 'a+V', 't+V', 'r+V', 'e+V', 'rivelavate+V', 'b+V', 'f+V', 'gargarizzavano+V', 'e+V', 'd+V', 'c+A', 'r+V', 'e+V', 'e+V', 'e+V', 'f+A', 'a+N', 'p+A', 'r+V', 'c+V', 'o+N', 'ristori+V', 'b+N', 'g+A', 'sottovalutazione+V', 'c+V', 'b+V', 'i+V', 'e+V', 'm+V', 'e+V', 'c+V', 'e+V', 'c+V', 'c+V', 'e+V', 'e+N', 'e+V', 'e+V', 'r+V', 'o+A', 'e+V', 'e+V', 'e+V', 'c+N', 'ardissi+V', 'sciupino+V', 'r+V', 'sottraesti+V', 'torrefano+V', 'v+A', 'romanzo+V', 'a+V', 'g+A', 'e+V', 'e+V', 'e+V', 'r+V', 'generanti+V', 'm+V', 'e+V', 'r+V', 'assaporarono+V', 'buttan+V', 'e+V', 'e+V', 'e+A', 'v+V', 'r+V', 'e+V', 'r+V', 'figurasser+V', 'minar+V', 'p+V', 'e+V', 's+V', 'immagazzineran+V', 'e+V', 'e+V', 'g+A', 'i+V', 'e+V', 'l+V', 'c+A', 'e+V', 'e+V', 'controfirmerò+V', 'borraste+V', 'sghignazzavano+V', 'e+V', 's+V', 'serra+V', 'e+V', 'r+V', 'o+A', 'l+N', 'svilivan+V', 'p+A', 'appureran+V', 'volassero+V', 'canticchiavate+V', 'a+A', 'e+V', 'e+V', 'e+V', 'e+V', 'c+A', 's+A', 'e+V', 'e+V', 'messa+V', 'cristallizzavi+V', 'e+V', 'c+N', 'giudicatrice+V', 'derapassi+V', 'e+V', 'e+V', 'g+A', 'r+V', 'e+V', 'e+V', 'e+V', 'c+V', 'inguainarono+V', 'a+V', 'f+N', 'e+V', 'mozzassero+V', 'dissecati+V', 'e+V', ' ...

# %%
# Out:
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# 'b'

# %%
a = [['1','0'],['1','0'],['1','1']]
sps.mode(a,axis=0)[0][0]
# Out:
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# '0'

# %%
# Out:
#    id             X            Y  P
# 0   0  vergognerete   vergognare  V
# 2   2   menomazione  menomazione  N

# %%
m = sprs.coo_matrix([[0,1],[0,0]])
print(m.toarray()[[0,1]])
# Out:
# [[0 1]
#  [0 0]]

# %%
a = pd.DataFrame([[1,3],[2,2],[3,1]])
a.head()
# Out:
#    0  1
# 0  1  3
# 1  2  2
# 2  3  1

# %%
a = [1,2,3,2]
sps.mode(a)[0][0]
# Out:
# 2
